# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def push(self,data):
        
        node = Node(data)
        
        node.next = self.head
        
        self.head = node
        
    def printlist(self):
        i = self.head
    
        while i!=None:
            print(i.data,end = "->")
            i = i.next
        print("Null")
        
    def loopdetection(self):
        
        follower = self.head
        forward = self.head.next
        
        while forward != None:
            
            if follower.next == self.head:
                return follower
            follower.next = self.head
            follower = forward
            forward = forward.next
            
        return None
    
    def planer(self,data):
        
        i = self.head
        while i != None:
            if i.data == data:
                return i
            i = i.next
        return None    
            
    
    
l = LinkedList()
l.push("E")
l.push("D")
l.push("C")
l.push("B")
l.push("A")
l.printlist()
i = l.head
while(i.next!=None):
    i = i.next    
i.next = l.planer("C")

n = l.loopdetection()
print(n.data)
# Out:
# A->B->C->D->E->Null
# C

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def push(self,data):
        node = Node(data)
        
        node.next = self.head
        
        self.head = node
        
    def createloop(self,data):
        
       
        ptr = self.head
        
        i = self.head
        while i.next != None:
            if ptr.data!=data:
                ptr = ptr.next
            elif ptr.data == data:
                ptr = ptr
            i = i.next
            
        i.next = ptr
       
        
    def printlist(self):
        
        i = self.head
        while i != None:
            print(i.data,end = "->")
            i = i.next
        print("Null")    
            
    def loopDetection(self):
        
        fast = self.head
        slow = self.head
        
        while fast != None or fast.next != None:
            fast = fast.next.next
            slow = slow.next
            if(fast == slow):
                break
        slow = self.head
        while fast != slow:
            slow = slow.next
            fast = fast.next
        
        return slow
        
l = LinkedList()
l.push("E")
l.push("D")
l.push("C")
l.push("B")
l.push("A")
l.printlist()
l.createloop("C")
node = l.loopDetection()
print(node.data)
# Out:
# A->B->C->D->E->Null
# C
