# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def push(self,data):
        node = Node(data)
        
        node.next = self.head
        
        self.head = node
    
    def printlist(self):
        it = self.head
        while it != None:
            print(it.data)
            it = it.next
    
    def intersection(self,head1,head2):
        
        i1 = head1.head
        count1 = 0
        count2 = 0
        
        while i1!=None:
            i2 = head2.head
            count1 += 1
            while i2 != None:
                if i1.data == i2.data:
                    return i1
                i2 = i2.next
            i1 = i1.next
        
        return None
         
    
l1 = LinkedList()
l2 = LinkedList()

l1.head = Node(1)
l1.push(2)
l1.push(3)
l1.push(4)
l1.push(5)

l2.head = Node(21)
l2.head.next = l1.head.next.next

l1.printlist()
l2.printlist()

intersect = l1.intersection(l1,l2)

print()
print(intersect)
# Out:
# 5
# 4
# 3
# 2
# 1
# 21
# 3
# 2
# 1
#
# 3

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def push(self):
        node = Node(data)
        
        node.next = self.head
        
        self.head = node
        
    def printlist(self):
        it = self.head
        while it!=None:
            print(it.data)
            it = it.next
            
    def intersection(self,head1,head2):
        
        head1 = self.intersection()
        
        if(head1.data != head2.data and (head1 != None and head2 != None)):
            
        
        if(head1.data == head2.data)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        
    def push(self,data):
        
        node = Node(data)
        
        node.next = self.head
        
        self.head = node
        
    def printlist(self):
        
        it = self.head
        while it != None:
            print(it.data)
            it = it.next
            
    def detectIntersection(self,list1,list2):
        
        sizeOflist1 = self.getSize(list1) 
        
        sizeOflist2 = self.getSize(list2)
        
        if sizeOflist1>sizeOflist2:
            long = self.shiftHead(list1,sizeOflist1-sizeOflist2)
            short = list2.head
        elif sizeOflist2>sizeOflist1:
            long = self.shiftHead(list2,sizeOflist2-sizeOflist)
            short = list1.head
            
            
        
        while long != None and short != None:
            if long == short:
                return long
            long = long.next
            short = short.next
     
        
        
    
    def shiftHead(self,head,difference):
        
        i = head.head
        amount = 0
        while head != None:
            if amount == difference:
                return i
            amount += 1
            i = i.next
        
        
    def getSize(self,l):
        
        i = l.head
        size = 0
        while i!=None:
            size += 1
            i = i.next
        return size
    
list1 = LinkedList()
list2 = LinkedList()

list1.push(1)
list1.push(2)
list1.push(7)
list1.push(9)
list1.push(5)
list1.push(1)
list1.push(3)

list1.printlist()

list2.push(6)
list2.push(4)
list2.head.next.next = list1.head.next.next.next.next
list2.head.next.next.next = list1.head.next.next.next.next.next
list2.head.next.next.next.next = list1.head.next.next.next.next.next.next


list2.printlist()
node = Node(None)
node = list1.detectIntersection(list1,list2)
print(node.data)
# Out:
# 3
# 1
# 5
# 9
# 7
# 2
# 1
# 4
# 6
# 7
# 2
# 1
# 7
