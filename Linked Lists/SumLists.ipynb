# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        
    def add(self,data):
        NewNode = Node(data)
        NewNode.next = None
        it = self.head
        while it.next != None:
            it = it.next
        it.next = NewNode    
        
    def printlist(self):
        it = self.head
        while it!=None:
            print(it.data)
            it = it.next
    
    
    def summation(self,data1,data2,list3):
        NewNode = Node(data1+data2)
        NewNode.next = list3.head
        list3.head = NewNode
         

list1 = LinkedList()
list1.head = Node(1)
list1.add(2)
list1.add(3)
list1.printlist()
            
print()    
list2 = LinkedList()    
list2.head = Node(4)
list2.add(5)
list2.add(6)
list2.printlist()

it1 = list1.head
it2 = list2.head
list3 = LinkedList()
list3.head = None
print()

while it1 != None and it2 != None:
    list3.summation(it1.data,it2.data,list3)
    it1 = it1.next
    it2 = it2.next
    
list3.printlist()    
            
"""    
list = LinkedList()
it1=list.head = Node(1)
list.add(2)
list.add(3)
list.printlist()


print()
list = LinkedList()
it2=list.head = Node(3)
list.add(9)
list.add(2)
list.printlist()


while (it1 != None) and (it2 != None):
    list.summation(it1.data,it2.data)
    it1 = it1.next
    it2 = it2.next
"""
# Out:
# 1
# 2
# 3
#
# 4
# 5
# 6
#
# 9
# 7
# 5
# '    \nlist = LinkedList()\nit1=list.head = Node(1)\nlist.add(2)\nlist.add(3)\nlist.printlist()\n\n\nprint()\nlist = LinkedList()\nit2=list.head = Node(3)\nlist.add(9)\nlist.add(2)\nlist.printlist()\n\n\nwhile (it1 != None) and (it2 != None):\n    list.summation(it1.data,it2.data)\n    it1 = it1.next\n    it2 = it2.next\n'

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def printlist(self):
        it = self.head
        while(it!=None):
            print(it.data)
            it = it.next
            
    def summation(list1,list2):
        
        it1 = list1.head
        it2 = list2.head
        n1 = 0
        n2 = 0
        list3 = LinkedList()
        list3.head = None
        while(it1 != None):
            n1 += 1
            it1 = it1.next
        
        while(it2 != None):
            n2 += 1
            it2 = it2.next
            
        it1 = list1.head
        it2 = list2.head
        if n1>n2:
            n3 = n1-n2
            it3 = list3.head
            for i in range(1,n3):
                it1 = it1.next
            while(it1!=None & it2!=None):
                ca = carry
                carry = 0
                data = it1.data + it2.data + ca
                if(data>10):
                    data = data-10
                    carry += 1
                NewNode = Node(data)
                NewNode.next = list3.head
                list3.head = NewNode
               
                it1 = it1.next
                it2 = it2.next
            old = it1
            if(it1.data>10):
                it.data
            it1 = list1.head
            while(it1!=old):
                data = it1.data
                NewNode = Node(data)
                NewNode.next = list3.head
                list3.head = NewNode
                it1 = it1.next    
            
            
        elif n1<n2:
            n3 = n2-n1
        elif n1==n2
            n3 = n2
            
        list3.printlist()

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
        
    def add(self,data):
        if self.head == None:
            self.head = Node(data)
        NewNode = Node(data)
        it = self.head
        while(it.next!=None):
            it = it.next
        it.next = NewNode    
    
    def contra(self,data):
        l = LinkedList()
        NewNode = Node(data)
        NewNode.next = l.head
        l.head = NewNode
    
    def correcter(self):
        it=self.head
        while it!=None:
            if(it.data>10):
                if(it.next == None):
                    it.data = it.data-10
                    it.next = Node(1)
                it.data = it.data-10
                it.next.data += 1
            it = it.next
        
    
    def addList3(self,l1,l2):
        list3 = LinkedList()
        
        last = l1.head
        while(last!=None):
            l1.contra(last.data)
            last = last.next
        last = l2.head
        while(last!=None):
            l2.contra(last.data)
            last = last.next
        print()    
        l1.printlist()
        print()
        l2.printlist()
        
        it = l1.head
        it2 = l2.head
        while it!=None:
            if(it2==None):
                list3.add(it.data)
            list3.add(it.data+it2.data)
            it = it.next
            it2 = it2.next
        
        list3.correcter()
        list3.print()
    
    def addListEqual3(self,list1,list2):
        i1 = list1.head
        i2 = list2.head
        list3 = LinkedList()
        data=0
        while i1!=None and i2!=None:
            list1.contra(i1.data)
            list2.contra(i2.data)
            i1 = i1.next
            i2 = i2.next
            
        i1 = list1.head
        i2 = list2.head
        
        while i1!=None and i2 !=None:
            data = i1.data+i2.data
            list3.add(data)
            i1 = i1.next
            i2 = i2.next
        list3.correcter()
        list3.printlist()
        
        
    def printlist(self):
        i = self.head
        while(i!=None):
            print(i.data)
            i = i.next
            
    def summation(self,list1,list2):
        i1 = list1.head
        i2 = list2.head
        n1 = 0
        n2 = 0
        list3 = LinkedList()
        while(i1!=None):
            i1 = i1.next
            n1 += 1
        while(i2!=None):
            i2 = i2.next
            n2 += 1
        
        if(n1>n2):
            list3.addList3(list1,list2)
        elif(n2>n1):
            list3.addList3(list2,list1)
        elif(n1==n2):    
            list3.addListEqual3(list1,list2)
        
list1 = LinkedList()
list2 = LinkedList()
list3 = LinkedList()

list1.add(1)
list1.add(9)
list1.add(5)

list2.add(9)
list2.add(4)
list2.add(6)

list3.summation(list1,list2)
# Out:
# 10
# 10
# 10
# 3
# -8
# 2

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None


class LinkedList:
    
    def __init__(self):
        self.head1 = None
        self.head2 = None
        self.head = None
            
    def addTwoLists(self,first,second):
          
            start1 = Node(0)
            start1.next = first
            start2 = Node(0)
            start2.next = second
      
        
            list.addPrecedingZeros(start1,start2)
            result = Node(0)
            if(list.sumTwoNodes(start1.next,start2.next,result)==1):
                NewNode = Node(1)
                NewNode.next = result.next
                result.next = NewNode
            list.printlist(result.next)    
            
    def sumTwoNodes(self,first,second,result):
            if first == None:
                return 0
            number = first.data + second.data + self.sumTwoNodes(first.next,second.next,result)
            node = Node(number%10)
            node.next = result.next
            result.next = node
            return int(number/10)
        
        
    def addPrecedingZeros(self,start1,start2):
            next1 = start1.next
            next2 = start2.next
            
            while next1!=None and next2!=None:
                next1 = next1.next
                next2 = next2.next
            if next1 == None and next2!=None:
                while next2 != None:
                    NewNode = Node(0)
                    NewNode.next = start1.next
                    start1.next = NewNode
                    next2 = next2.next
            elif next2 == None and next1 != None:
                while next1 != None:
                    NewNode = Node(0)
                    NewNode.next = start2.next
                    start2.next = NewNode
                    next1 = next1.next
                
    
    def addNodeHead1(self,data):
        node = Node(data)
        it = self.head1
        while it.next != None:
            it = it.next
        it.next = node    
    
    def addNodeHead2(self,data):
        node = Node(data)
        it = self.head2
        while it.next != None:
            it = it.next
        it.next = node    
    
    def printlist(self,head):
        it = head
        while it != None:
            print(it.data)
            it = it.next
            
    
list = LinkedList()


first = list.head1 = Node(7)
list.addNodeHead1(5)
list.addNodeHead1(9)
list.addNodeHead1(4)
list.addNodeHead1(6)

list.printlist(list.head1)


second = list.head2 = Node(8)
list.addNodeHead2(4)

list.printlist(list.head2)

list = LinkedList()
list.addTwoLists(first,second)
# Out:
# 7
# 5
# 9
# 4
# 6
# 8
# 4
# 9
# 4
# 6
# 7
# 6
# 0
# 3
# 0
