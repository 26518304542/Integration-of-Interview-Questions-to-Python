# %%
class Node():
    def __init__(self,dataval=None):
        self.dataval = dataval
        self.nextval = None
        
class LinkedList():
    def __init__(self):
        self.headval = None
        
    def addNode(self,dataval):
        NewNode = Node(dataval)
        iterator = self.headval
        while(iterator.nextval):
            iterator = iterator.nextval
        iterator.nextval = NewNode
        
    def deleteNode(self,removekey):
        iterator = self.headval
        while iterator is not None:
            if iterator.dataval == removekey:
                break
            iterator = iterator.nextval
        
        temp = iterator
        iterator = iterator.nextval
        
        temp.nextval = iterator.nextval
        iterator = None
        
        
        
    def printlist(self):
        iterator = self.headval
        while(iterator is not None):
            print(iterator.dataval)
            iterator = iterator.nextval
            
    
    def removedup(self):
        """
        iterator = self.headval
        i=0
        while(iterator.nextval):
            i += 1
            iterator = iterator.nextval
        matrix = [i*0]
        iterator = self.headval
        i = 0
        while(iterator.nextval):
            index_num = matrix[iterator.dataval] += 1
            if(index_num > 1):
                deleteNode(iterator.dataval)
            iterator = iterator.nextval
        """
        current = self.headval
        runner = None  
        dup = None
        
        while current and current.nextval is not None:
                runner = current 
            
                while runner and runner.nextval is not None:
                
                    if current.dataval == runner.nextval.dataval:
                        runner.nextval = runner.nextval.nextval
                
                    else:
                        runner = runner.nextval
            
                current = current.nextval            
        """
        while (current != None and current.nextval != None):
 
            runner = current
 
            # Compare the picked element with rest
            # of the elements
            while (runner.nextval != None):
 
                # If duplicate then delete it
                if (current.dataval == runner.nextval.dataval):
 
                    # Sequence of steps is important here
                    dup = runner.nextval
                    runner.nextval = runner.nextval.nextval
                else:
                    runner = runner.nextval
 
            current = current.nextval
        """
            

list = LinkedList()
list.headval = Node("1")
list.addNode("2")
list.addNode("2")
list.addNode("3")
list.addNode("4")
list.addNode("5")
list.addNode("5")
list.addNode("6")
list.addNode("8")

list.removedup()

list.printlist()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8

# %%
# Python3 program to remove duplicates
# from unsorted linked list


class Node():

	def __init__(self, data):

		self.data = data
		self.next = None


class LinkedList():

	def __init__(self):

		# Head of list
		self.head = None

	def remove_duplicates(self):

		ptr1 = None
		ptr2 = None
		dup = None
		ptr1 = self.head

		# Pick elements one by one
		while (ptr1 != None and ptr1.next != None):

			ptr2 = ptr1

			# Compare the picked element with rest
			# of the elements
			while (ptr2.next != None):

				# If duplicate then delete it
				if (ptr1.data == ptr2.next.data):

					# Sequence of steps is important here
					dup = ptr2.next
					ptr2.next = ptr2.next.next
				else:
					ptr2 = ptr2.next

			ptr1 = ptr1.next

	# Function to print nodes in a
	# given linked list
	def printList(self):
		temp = self.head

		while(temp != None):
			print(temp.data, end=" ")
			temp = temp.next

		print()


# Driver code
list = LinkedList()
list.head = Node(10)
list.head.next = Node(12)
list.head.next.next = Node(11)
list.head.next.next.next = Node(11)
list.head.next.next.next.next = Node(12)
list.head.next.next.next.next.next = Node(11)
list.head.next.next.next.next.next.next = Node(10)

print("Linked List before removing duplicates :")
list.printList()
list.remove_duplicates()
print()
print("Linked List after removing duplicates :")
list.printList()

# This code is contributed by maheshwaripiyush9
# Out:
# Linked List before removing duplicates :
# 10 12 11 11 12 11 10
#
# Linked List after removing duplicates :
# 10 12 11
