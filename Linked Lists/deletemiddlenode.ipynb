# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class SLinkedList:
    def __init__(self):
        self.head = None
        
    def add(self,data):
        NewNode = Node(data)
        NewNode.next = self.head
        self.head = NewNode
    
    def deletemid(self,data):
    
        
        if(self.head.next == None):
            return
        elif(data==self.head.data):
            return
        elif(self.head.data == data):
            return
        
        
        MidNode = self.deletemid(self.head.next)
        if(self.head.next.data==data):
            self.head.next.next = self.head.next.next.next
            return self.head.next
        return MidNode
    
    def printlist(self):
        it = self.head
        while it is not None:
            print(it.data)
            it = it.next
            
list = SLinkedList()
list.head = Node("n")
list.add("i")
list.add("e")
list.add("l")
list.add("l")
list.add("A")

list.printlist()
list.deletemid("e")
list.printlist()
# Out:
# A
# l
# l
# e
# i
# n
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-1-a6b90288bfdf> in <module>
#      45
#      46 list.printlist()
# ---> 47 list.deletemid("e")
#      48 list.printlist()
#      49
#
# <ipython-input-1-a6b90288bfdf> in deletemid(self, data)
#      24
#      25
# ---> 26         MidNode = self.deletemid(self.head.next)
#      27         if(self.head.next.data==data):
#      28             self.head.next.next = self.head.next.next.next
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-1-a6b90288bfdf> in deletemid(self, data)
#      24
#      25
# ---> 26         MidNode = self.deletemid(self.head.next)
#      27         if(self.head.next.data==data):
#      28             self.head.next.next = self.head.next.next.next
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
    
class SLinkedList:
    def __init__(self):
        self.head = None
        
    def add(self,data):
        NewNode = Node(data)
        NewNode.next = self.head
        self.head = NewNode
        
    def deletemid(self,head,data):
        
        head = self.head
        if self.head == None:
            return None
        if head.next == None:
            head = self.head
            return head
        if(head==self.head):
            head = list.deletemid(head.next,data)
            return head
        if (head!=self.head):
            
            if head.data == data:
                head.next = head.next.next
                head = self.head
                return head
            head = self.deletemid(head.next,data)
                    
    def printlist(self):
        self.head = head
        it = self.head
        while it is not None:
            print(it.data)
            it = it.next

list = SLinkedList()
list.head = Node("n")
list.add("i")
list.add("e")
list.add("l")
list.add("l")
list.add("A")
head = list.head

list.printlist()
list.deletemid(head,"e")
print()
list.printlist()

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def add(self,data):
        it = self.head
        while(it.next is not None):
            it = it.next
        NewNode = Node(data)
        NewNode.next = None
        it.next = NewNode
    def printlist(self):
        it = self.head
        while it is not None:
            print(it.data)
            it = it.next
            
    def deletemid(self,data):
        it = self.head
        while it.next is not None:
            it = it.next
        if(self.head == data):
            return
        if(it.data == data):
            return
        it = self.head
        while it is not None:
            if it.next != None:
                if it.next.data == data:
                    it.next = it.next.next
                    return
            it = it.next
            
list = LinkedList()
list.head = Node("A")
list.add("l")
list.add("l")
list.add("e")
list.add("i")
list.add("n")

list.printlist()
list.deletemid("A")
print()
list.printlist()

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None
    
    def add(self,data):
        it = self.head
        while(it.next is not None):
            it = it.next
        NewNode = Node(data)
        NewNode.next = None
        it.next = NewNode
    def printlist(self):
        it = self.head
        while it is not None:
            print(it.data)
            it = it.next
            
    def deletemid(self,data):
        it = self.head
        while it.next is not None:
            it = it.next
        if(self.head == data):
            return
        if(it.data == data):
            return
        it = self.head
        while it is not None:   
            if it.data == data:
                it = it.next
                return
            it = it.next
            
list = LinkedList()
list.head = Node("A")
list.add("l")
list.add("l")
list.add("e")
list.add("i")
list.add("n")

list.printlist()
list.deletemid("A")
print()
list.printlist()
# Out:
# A
# l
# l
# e
# i
# n
#
# A
# l
# l
# e
# i
# n
