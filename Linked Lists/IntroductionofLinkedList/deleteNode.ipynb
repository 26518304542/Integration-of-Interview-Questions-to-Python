# %%
class Node:
    def __init__(self,dataval=None):
        self.dataval = dataval
        self.nextval = None

class LinkedList:
    def __init__(self):
        self.headval = None
        
    def addEnd(self,dataval):
        if self.headval is None:
            self.headval = Node(dataval)
            return
        
        NewNode = Node(dataval)
        it = self.headval
        
        while(it.nextval):
            it = it.nextval
        it.nextval = NewNode
        
    def addInBetween(self,middle_node,newdata):
        if self.headval.nextval is None:
            return
         
        elif self.headval is middle_node:
            list.addEnd(newdata)
                
        
        NewNode = Node(newdata)
        it = self.headval
        
        while(it.nextval is not middle_node.nextval):
            it = it.nextval
        
        NewNode.nextval = it.nextval
        it.nextval = NewNode
        
    def deleteNode(self,newdata):
        it = self.headval
        
        while it is not None:
            if it.dataval == newdata:
                break
            temp = it   
            it = it.nextval
        temp.nextval = it.nextval    
        it = None  
            
       
    
    def printlist(self):
        it = self.headval
        while it is not None: 
            print(it.dataval)
            it = it.nextval
            
        

list = LinkedList()
list.headval = Node("A")

list.addEnd("l")
list.addEnd("l")
list.addEnd("a")
list.addEnd("i")
list.addEnd("n")

list.addInBetween(list.headval.nextval.nextval,"Q")

list.printlist()

list.deleteNode("l")

list.printlist()
# Out:
# A
# l
# l
# Q
# a
# i
# n
# A
# l
# Q
# a
# i
# n
