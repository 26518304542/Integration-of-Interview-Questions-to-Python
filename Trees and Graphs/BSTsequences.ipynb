# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = self.right = None
        
class Queue:
    def __init__(self):
        self.head = None

# %%
# Python program to find BST keys in given range

# A binary tree node
class Node:

	# Constructor to create a new node
	def __init__(self, data):
		self.data = data
		self.left = None
		self.right = None

# The function prints all the keys in the given range
# [k1..k2]. Assumes that k1 < k2
def Print(root, k1, k2):
	
	# Base Case
	if root is None:
		return

	# Since the desired o/p is sorted, recurse for left
	# subtree first. If root.data is greater than k1, then
	# only we can get o/p keys in left subtree
	if k1 <= root.data :
		Print(root.left, k1, k2)

	# If root's data lies in range, then prints root's data
	if k1 <= root.data and k2 >= root.data:
		print (root.data,end=' ')

	# recursively call the right subtree
	Print(root.right, k1, k2)

# Driver function to test above function
k1 = 10  
k2 = 25 
root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(4)
root.left.right = Node(12)

Print(root, k1, k2)

# This code is contributed by Nikhil Kumar Singh(nickzuck_007)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = self.right = None

class ll_Node:
    def __init__(self,key):
        self.key = key
        self.next = None
        
class ArrayList:
    def __init__(self):
        self.head = None
        self.root_for_arraylist=None
        self.al_next = None
        self.size = 0
    
    def size(self):
        i = self.head
        while i.connect:
            self.size += 1
            i = i.connect
    
    def addAll(self,arrayList):
        if self.root_for_arraylist == None:
            self.root_for_arraylist = arrayList
        else:
            i = self.root_for_arraylist
            while i.al_next:
                i = i.al_next
            i.al_next = arrayList    
            
            
        
    def add(self,linkedlist):
        if self.head == None:
            self.head = linkedlist
        else:
            i = self.head
            while i.connect:
                i = i.connect
            i.connect = linkedlist    
            
    
    def printlist(self):
        i = self.head
        while i!=None:
            il = i.root
            while il!=None:
                print(il.key,end="\t")
                il = il.next
            print()
            i = i.connect
    
    
    def allSequences(self,node):
        result = ArrayList()
        
        if node==None:
            linkedlist = LinkedList()
            result.add(linkedlist)
            print("3")
            return result
        
        prefix = LinkedList()
        prefix.add(node.data)
        
        leftSeq = self.allSequences(node.left)
        rightSeq = self.allSequences(node.right)
        
        i1 = leftSeq.head
        i2 = rightSeq.head
        while i1!=None:
            while i2!=None:
                weaved = ArrayList()
                self.weaveList(i1,i2,weaved,prefix)
                result.addAll(weaved)
                print("2")
                i2 = i2.connect
            i1 = i1.connect
            
            
        return result
    
    
    def weaveList(self,first,second,results,prefix):
        
        if first.size==0 or second.size==0:
            result = prefix.clone()
            if result!=None:
                result.addAll(first)
                result.addAll(second)
                results.add(result)
                i = result.root_for_arraylist
                while i!=None:
                    print("1")
                    i = i.al_next
            return
        
        headFirst = first.removeFirst()
        prefix.addLast(headFirst)
        self.weaveList(first,second,results,prefix)
        prefix.removeLast()
        first.addFirst(headFirst)
        
        headSecond = second.removeFirst()
        prefix.addLast(headSecond)
        self.weaveList(first,second,results,prefix)
        prefix.removeLast()
        second.addFirst(headSecond)
        
        

class LinkedList:
    def __init__(self):
        self.root = None
        self.connect = None
        self.root_for_linkedlist = None
        self.size = self.size()
       
    def clone(self):
        i = self.root
        clone = LinkedList()
        while i!=None:
            clone.add(i.key)
            i = i.next
    
    def size(self):
        self.size = 0
        i = self.root
        while i!=None:
            self.size += 1
            i = i.next
        return self.size    
            
        
    def add(self,data):
        if self.root == None:
            self.root = ll_Node(data)
        else:
            i = self.root
            while i.next:
                i = i.next
            i.next = ll_Node(data)
           
    def addAll(self,linkedList):
        if self.root_for_linkedlist==None:
            self.root_for_linkedlist = linkedList
        else:
            i = self.root_for_linkedlist
            while i.connect:
                i = i.connect
            i.connect = linkedList    
            
    def addFirst(self,data):
        node = ll_Node(data)
        node.next = self.root
        self.root = node
    
    
    def addLast(self,data):
        node = ll_Node(data)
        i = self.root
        while i.next:
            i = i.next
        i.next = node    
    
    
    def removeFirst(self):
        i = self.root
        self.root = self.root.next
        return i.key
        
    
    def removeLast(self):
        i = self.root
        while i.next.next:
            i=i.next
        ii = i.next    
        i.next = None
        return ii.key
    
    
root = Node(5)
root.left = Node(4)
root.right = Node(6)

a = ArrayList()
a.allSequences(root)

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        

class LinkedList:
    def __init__(self):
        self.next = None
        self.head = None
        
    def addLast(self,data):
        if self.head == None:
            self.head = Node(data)
        else:
            i = self.head
            while i.right or i.next or i.connect:
                if i.right:
                    i = i.right
                elif i.next:
                    i = i.next
                elif i.connect:
                    i = i.connect
            if i.right == None:        
                i.right = Node(data)
            elif i.next == None:
                i.next = Node(data)
            elif i.connect == None:
                i.connect = Node(data)
                
            
            
    def addFirst(self,data):
        if self.head == None:
            self.head = Node(data)
        else:
            n = Node(data)
            n.right = self.head
            self.head = n
            
    def removeLast(self):
        if self.head == None:
            return
        if self.head.right == None or self.head.next or self.head.connect:
            n = self.head.data
            self.head = None
            return n
        i = self.head
        slow = self.head
        while i.right or i.next or i.connect:
            if i.right:
                slow = i
                i = i.right
            elif i.next:
                slow = i
                i = i.next
            elif i.connect:
                slow = i
                i = i.connect
       
        if slow.right==i:
            n = i.data
            slow.right = None
            return n
        elif slow.next==i:
            if i.head == None:
                return
            n = i.head.data
            slow.next = None
            return n
        elif slow.connect==i:
            
    
    def removeFirst(self):
        if self.head == None:
            return
        if self.head.right == None:
            n = self.head.data
            self.head = None
            return n
        i = self.head
        self.head = i.right
        return i.data
    
    
    def addLinkedList(self,l):
        if self.head == None:
            self.head = l
        else:
            i = self.head
            while i.next or i.right:
                if i.next:
                    i = i.next
                elif i.right:
                    i = i.right
                    
            if i.next==None:
                i.next = l
            elif i.right==None:
                i.right = l
            elif i.connect==None:
                i.connect = l
                

    def addArrayList(self,a):
        if self.head == None:
            self.head = a
        else:
            i = self.head
            while i.next:
                i = i.next
            i.next = a    
    
    
    
class ArrayList:
    def __init__(self):
        self.root = None
        self.connect = None

    
    def addLinkedList(self,l):
        if self.root == None:
            self.root = l
        else:
            i = self.root
            while i.next or i.right:

    def addArrayList(self,a):

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
        
class LinkedList:
    def __init__(self):
        self.head = None
        self.next = None
        
    def addFirst(self,data):
        n = Node(data)
        n.right = self.head
        self.head = n
        
    def removeFirst(self):
        n = self.head
        self.head = n.right
        n.right = None
        return n.data
    
    def addLast(self,data):
        n = Node(data)
        i = self.head
        while i.right:
            i = i.right
        i.right = n
        
    def removeLast(self):
        i = self.head
        while i.right.right == None:
            i = i.right
        n = i.right    
        i.right = None
        return n.data
    
class ArrayList:
    def __init__(self):
        self.root = None
        self.connect = None
        
    def add(self,l):
        if self.root == None:
            self.root = l
        else:
            i = self.root
            while i.next:
                i = i.next
            i.next = l
            
    def addAll(self,al):
        if self.root == None:
            self.root = al
        else:
            i = self.root
            while i.connect:
                i = i.connect
            i.connect = al
            
    def remove(self):
        if self.root == None:
            return
        i = self.root
        while i.next.next==None:
            i = i.next
        n = i.next    
        i.next = None
        return n
            
    def removeAll(self):
        if self.root == None:
            return
        i = self.root
        while i.connect.connect==None:
            i = i.connect
        n = i.connect
        i.connect = None
        return n

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
        
class LinkedList:
    def __init__(self):
        self.root = None
        self.right = None
        
def allSequences(node):
    result = LinkedList()
    
    if node == None:
        result.root = LinkedList()
        return result
    
    prefix = LinkedList()
    i = prefix.root
    if i!=None:
        while i.right != None:
            i = i.right
        i.right = Node(node.data)    
    else:
        prefix.root = Node(node.data)
        
    
    
    
    leftSeq = allSequences(node.left)
    rigthSeq = allSequences(node.right)
    
    left = leftSeq.root
    right = rigthSeq.root
    while left!=None:
        while right!=None:
            weaved = LinkedList()
            weaveList(left,right,weaved,prefix)
            r = result.root
            if i!=None:
                while r.right!=None:
                    r = r.right
                r.right = weaved
            else:
                result.root = weaved
            
            right = right.right
        
        left = left.right
        
    return result

def weaveList(left,right,weaved,prefix):

    if left.root==None or right.root==None:
        result = LinkedList()
        i = prefix.root
        r = result.root
        if i!=None:
            while i!=None:
                if r==None:
                    result.root = Node(i.data)
                    r = result.root
                else:
                    r.right = Node(i.data)
                    
                i = i.right
        r.right = left
        left.right = right
        w = weaved.root
        if w!=None:
            while w.right:
                w = w.right
            w.right = result
        else:
            weaved.root = result
        return 
    
    
    
    headFirst = left.root
    left.root = left.root.right
    p = prefix.root
    
    while p.right:
        p = p.right
        
    p.right = Node(headFirst)
    last = p.right
    
    weaveList(left,right,weaved,prefix)
    p.right = None
    n = Node(headFirst)
    n.right = left.root
    left.root = n
    
    
    
    
    headSecond = right.root
    right.root = right.root.right
    p = prefix.root
    
    while p.right:
        p = p.right
        
    p.right = Node(headSecond)
    last = p.right

    weaveList(left,right,weaved,prefix)
    p.right = None
    n = Node(headSecond)
    n.right = right.root
    right.root = n
    

def printList(l):
    
    i = l.root
    i2 = i.root
    
    while i!=None:
        i2 = i.root
        while i2!=None:
            il = i2.root
            while il!=None:
                print(il.data,end="\t")
                il = il.right
            print()
            i2 = i2.right
        i = i.right    
    
    

root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(4)
root.left.right = Node(12)
our_list = allSequences(root)
printList(our_list)
# Out:
# 20
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-c53bbf501c6d> in <module>
#     140 root.left.right = Node(12)
#     141 our_list = allSequences(root)
# --> 142 printList(our_list)
#     143
#     144
#
# <ipython-input-1-c53bbf501c6d> in printList(l)
#     126             il = i2.root
#     127             while il!=None:
# --> 128                 print(il.data,end="\t")
#     129                 il = il.right
#     130             print()
#
# AttributeError: 'LinkedList' object has no attribute 'data'

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = self.right = None
        self.description = "Node"

class LinkedList:
    def __init__(self):
        self.root = None
        self.next = None
        self.description = "LinkedList"
        
    def add_LL(self,l):
        print("add_LL begin")
        if self.root == None:
            self.root = l
        else:
            i = self.root
            num = 0
            a=self.root
            while i!=None:
                if i.description=="Node":
                        if i.right==None:
                            break
                        print("add_LL right")
                        i= i.right
                elif i.description=="LinkedList":
                        if i.next==None:
                            break
                        print("add_LL next")
                        i = i.next
                        
                    
            if a.description=="Node":
                a.right = l
            elif a.description=="LinkedList":
                a.next = l
                        
                    
                
        
        
    def add(self,data):
        
        if self.root==None:
            self.root = Node(data)
        else:
            i = self.root
            while i!=None:
                if i.description=="Node":
                    if i.right==None:
                        break
                    i = i.right
                elif i.description=="LinkedList":
                    if i.next == None:
                        break
                    i = i.next
                        
            if i.description=="Node":    
                i.right = Node(data) 
            elif i.description=="LinkedList":
                i.next = Node(data)
            
            
                    
    
    def removeFirst(self):
        
        if self.root==None:
            return
        else:
            i = self.root
            if i.description=="Node":
                self.root = i.right
            elif i.description=="LinkedList":
                self.root = i.next
        if i.description=="LinkedList":
            return i.root.data
        elif i.description=="Node":
            return i.data
            
        
    
        
        
    def removeLast(self):
        
        if self.root == None:
            return
        else:
            i = self.root
            while i!=None:
                if i.description=="Node":
                    if i.right==None:
                        break
                    i = i.right
                elif i.description=="LinkedList":
                    if i.next==None:
                        break
                    i = i.next
                    
            it = self.root
            while it!=None:
                if it.description=="Node":
                    if it.right==i:
                        break
                    it = it.right
                elif it.description=="LinkedList":
                    if it.next==i:
                        break
                    it = it.next
                    
            if it.description=="Node":
                it.right = None
            elif it.description=="LinkedList":
                it.next = None
            if i.next==None:
                return i.root.data
            elif i.right==None:
                return i   
    
    def clone(self):
        l = LinkedList()
        i = self.root
        if self.root==None:
            return l
        else:
            while i.right:
                l.add(i.data)
                i = i.right
            return l    
        
        
        
class LinkedListContainer:
    def __init__(self):
        self.head = None
        self.nachste = None
        self.description = "LinkedListContainer"
    
    def hinzufugen(self,l):
        print("hinzufügen")
        if self.head == None:
            self.head = l
        else:
            i = self.head
            while i!=None:
                if i.description == "LinkedListContainer":
                    if i.nachste==None:
                        break
                    i = i.nachste
                elif i.description == "LinkedList":
                    if i.next==None:
                        break
                    i = i.next    
            
            if i.description == "LinkedListContainer":
                i.nachste = l
            elif i.description == "LinkedList":
                i.next = l
            
        
        
def BST_sequence(node):
    
    results = LinkedListContainer()
    
    if node==None:
        l = LinkedList()
        results.hinzufugen(l)
        return results
    
    prefix = LinkedList()
    print(node.data)
    prefix.add(node.data)
    
    leftSeq = BST_sequence(node.left)
    rightSeq = BST_sequence(node.right)
    
    left = leftSeq.head
    right = rightSeq.head
    
    while left!=None:
        while right!=None:
            print("weaved")
            weaved = LinkedListContainer()
            weavedList(left,right,weaved,prefix)
            results.hinzufugen(weaved)
            if right.description=="LinkedList":
                right = right.next
            elif right.description=="LinkedListcontainer":
                right = right.nachste
        if left.description=="LinkedList":        
            left = left.next
        elif left.description=="LinkedListContainer":
            left = left.nachste
    
    return results 


def weavedList(left,right,weaved,prefix):
    
    if left.description=="LinkedList" and right.description=="LinkedList":
        if left.root == None or right.root == None:
            result = prefix.clone()
            result.add_LL(left)
            print("result.add_LL(left)")
            result.add_LL(right)
            print("result.add_LL(right)")
            weaved.hinzufugen(result)
            return
    elif left.description=="LinkedListContainer" and right.description=="LinkedListContainer":
        if left.head == None or right.head == None:
            result = prefix.clone()
            result.add_LL(left)
            print("result.add_LL(left)")
            result.add_LL(right)
            print("result.add_LL(right)")
            weaved.hinzufugen(result)
            return
    
    headFirst = left.removeFirst()
    print(headFirst)
    prefix.add(headFirst)
    weaveList(left,right,weaved,prefix)
    prefix.removeLast()
    left.addFirst(headFirst)
    
    
    headSecond = right.removeFirst()
    print(headSecond)
    prefix.add(headFirst)
    weaveList(left,right,weaved,prefix)
    prefix.removeLast()
    right.addFirst(headSecond)
    

def viewList(results):
    
    i = results.head
    while i!=None:
        it = i.root
        while it!=None:
            print(it.data,end="/t")
            it = it.right
        print()    
        i = i.next    
    
    
    
    

root = Node(20)
root.left = Node(8)
root.right = Node(22)
root.left.left = Node(4)
root.left.right = Node(12)
results = BST_sequence(root)
viewList(results)
# Out:
# 20
# 8
# 4
# hinzufügen
# hinzufügen
# weaved
# add_LL begin
# result.add_LL(left)
# add_LL begin
# result.add_LL(right)
# hinzufügen
# hinzufügen
# 12
# hinzufügen
# hinzufügen
# weaved
# add_LL begin
# result.add_LL(left)
# add_LL begin
# result.add_LL(right)
# hinzufügen
# hinzufügen
# weaved
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-64945e5eaf2c> in <module>
#     256 root.left.left = Node(4)
#     257 root.left.right = Node(12)
# --> 258 results = BST_sequence(root)
#     259 viewList(results)
#     260
#
# <ipython-input-6-64945e5eaf2c> in BST_sequence(node)
#     175     prefix.add(node.data)
#     176
# --> 177     leftSeq = BST_sequence(node.left)
#     178     rightSeq = BST_sequence(node.right)
#     179
#
# <ipython-input-6-64945e5eaf2c> in BST_sequence(node)
#     185             print("weaved")
# ...
