# %%
class Stack:
    
    def __init__(self,size):
        self.size = size
        self.array = size*[]
        self.last = 0
        self.min = None
        self.minprev = None
        
    def push(self,val):
        
        if isEmpty():
            self.array[self.last] = val
            self.last += 1
            self.min = self.array[self.last]
        
        self.array[self.last] = val
        self.last += 1
        if self.min > val:
            self.min = val
            
        
    def popMin(self):
        
        val = self.min

# %%
class Stack:
    
    def __init__(self,capacity):
        self.capacity = capacity
        self.values = [0]*self.capacity
        self.last = 0
        
    def push(self,element):
        
        self.values[self.last] = element
        self.last += 1
        
    def printlist(self):
        i=0
        it = self.values[i]
        while(i!=self.last):
            print(it)
            it = self.values[i+1]
            i += 1
            
    def pop(self):
        element = self.values[self.last-1]
        self.values[self.last-1] = 0
        self.last -= 1
        return element
    
    def defmin(self):
        i = 1
        minval = self.values[0]
        while(i!=self.last):
            
            if self.values[i]<minval:
                minval = self.values[i]
            i += 1
              
            
        return minval    
        
        

s = Stack(5)
s.push(3)
s.printlist()
print()
s.push(2)
s.printlist()
print()
s.push(1)
s.printlist()
print()
m = s.defmin()
print(m)
print()
popelement = s.pop()
print(popelement)
print()
m2 = s.defmin()
print(m2)
print()
p = s.pop()
print(p)
# Out:
# 3
#
# 3
# 2
#
# 3
# 2
# 1
#
# 1
#
# 1
#
# 2
#
# 2
